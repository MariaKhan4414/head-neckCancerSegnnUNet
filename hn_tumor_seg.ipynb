# %%
# !pip install nnUNetv2

# %%
# !pip install --upgrade git+https://github.com/FabianIsensee/hiddenlayer.git

# %%
# !ls /usr/local/lib/python3.11/dist-packages/nnunetv2/training/nnUNetTrainer
# Out:
# __init__.py  nnUNetTrainer.py  __pycache__  variants

# %%
# %cd /usr/local/lib/python3.11/dist-packages/nnunetv2/training/nnUNetTrainer
# Out:
# /usr/local/lib/python3.11/dist-packages/nnunetv2/training/nnUNetTrainer

# %%
# !sed -i 's/self.num_epochs = 1000/self.num_epochs = 400/g' nnUNetTrainer.py
# !sed -i 's/self.num_iterations_per_epoch = 250/self.num_iterations_per_epoch = 100/g' nnUNetTrainer.py
# !sed -i 's/self.num_val_iterations_per_epoch = 50/self.num_val_iterations_per_epoch = 20/g' nnUNetTrainer.py

# %%
# !cat nnUNetTrainer.py

# %%
# %cd /content/
# Out:
# /content

# %%
# !git clone https://github.com/MIC-DKFZ/nnUNet.git
# Out:
# Cloning into 'nnUNet'...
# remote: Enumerating objects: 13663, done.
# remote: Total 13663 (delta 0), reused 0 (delta 0), pack-reused 13663 (from 1)
# Receiving objects: 100% (13663/13663), 7.87 MiB | 15.74 MiB/s, done.
# Resolving deltas: 100% (10478/10478), done.

# %%
# !mkdir nnUNet/nnUNet_raw
# !mkdir nnUNet/nnUNet_preprocessed
# !mkdir nnUNet/nnUNet_results

# %%
#!cp -r /content/drive/MyDrive/nnUnet/nnUNet_raw_74.zip ./nnUNet/

# %%
# %cd nnUNet
# Out:
# /content/nnUNet

# %%
#!unzip /content/drive/MyDrive/nnUnet/nnUNet_raw_74.zip -d /content/drive/MyDrive/nnUNet/

# %%
import os
os.environ['nnUNet_raw'] = "/content/nnUNet/nnUNet_raw"
os.environ['nnUNet_preprocessed'] = "/content/drive/MyDrive/nnUNet/nnUNet_preprocessed"
os.environ['nnUNet_results'] = "/content/drive/MyDrive/nnUNet/nnUNet_results"

# %%
#!nnUNetv2_preprocess -d 2 -c 3d_lowres --verbose

# %%
#!nnUNetv2_plan_and_preprocess -d 2 -c 3d_lowres --verbose #--verify_dataset_integrity

# %%
# !nnUNetv2_find_best_configuration 2 -c 2d

# %%
# !nnUNetv2_find_best_configuration 2 -c 2d 3d_fullres

# %%
# !nnUNetv2_find_best_configuration 2 -c 2d 3d_fullres 3d_lowres

# %%
# !nnUNetv2_find_best_configuration 2 -c 3d_cascade_fullres
# Out:
# ***All results:***
# nnUNetTrainer__nnUNetPlans__3d_cascade_fullres: 0.428103956712693
#
# *Best*: nnUNetTrainer__nnUNetPlans__3d_cascade_fullres: 0.428103956712693
#
# ***Determining postprocessing for best model/ensemble***
# WARNING: Not all files in folder_ref were found in folder_predictions. Determining postprocessing should always be done on the entire dataset!
# Results were improved by removing all but the largest foreground region. Mean dice before: 0.4281 after: 0.42812
#
# ***Run inference like this:***
#
# nnUNetv2_predict -d Dataset002_HN -i INPUT_FOLDER -o OUTPUT_FOLDER -f  0 1 2 3 4 -tr nnUNetTrainer -c 3d_cascade_fullres -p nnUNetPlans
#
# ***Once inference is completed, run postprocessing like this:***
#
# ...

# %%
# !nnUNetv2_predict -d Dataset002_HN -i '/content/drive/MyDrive/nnUNet/nnUNet_raw/Dataset002_HN/imagesTr/' -o '/content/drive/MyDrive/nnUNet/nnUNet_output' -f  0 1 2 3 4 -tr nnUNetTrainer -c 3d_lowres -p nnUNetPlans

# %%
# !nnUNetv2_apply_postprocessing -i '/content/drive/MyDrive/nnUNet/nnUNet_output' -o '/content/drive/MyDrive/nnUNet/nnUNet_output_pp' -pp_pkl_file /content/drive/MyDrive/nnUNet/nnUNet_results/Dataset002_HN/nnUNetTrainer__nnUNetPlans__3d_lowres/crossval_results_folds_0_1_2_3_4/postprocessing.pkl -np 8 -plans_json /content/drive/MyDrive/nnUNet/nnUNet_results/Dataset002_HN/nnUNetTrainer__nnUNetPlans__3d_lowres/crossval_results_folds_0_1_2_3_4/plans.json

# %%
# !nnUNetv2_train 2 3d_cascade_fullres 0 --npz --c
# Out:
# ############################
# INFO: You are using the old nnU-Net default plans. We have updated our recommendations. Please consider using those instead! Read more here: https://github.com/MIC-DKFZ/nnUNet/blob/master/documentation/resenc_presets.md
# ############################
#
# Using device: cuda:0
#
# #######################################################################
# Please cite the following paper when using nnU-Net:
# Isensee, F., Jaeger, P. F., Kohl, S. A., Petersen, J., & Maier-Hein, K. H. (2021). nnU-Net: a self-configuring method for deep learning-based biomedical image segmentation. Nature methods, 18(2), 203-211.
# #######################################################################
#
# 2025-03-27 19:13:44.277963: Using torch.compile...
# 2025-03-27 19:14:06.659057: do_dummy_2d_data_aug: True
# 2025-03-27 19:14:06.666821: Using splits from existing split file: /content/drive/MyDrive/nnUNet/nnUNet_preprocessed/Dataset002_HN/splits_final.json
# ...

# %%
# !nnUNetv2_train 2 3d_cascade_fullres 1 --npz --c
# Out:
# ############################
# INFO: You are using the old nnU-Net default plans. We have updated our recommendations. Please consider using those instead! Read more here: https://github.com/MIC-DKFZ/nnUNet/blob/master/documentation/resenc_presets.md
# ############################
#
# Using device: cuda:0
#
# #######################################################################
# Please cite the following paper when using nnU-Net:
# Isensee, F., Jaeger, P. F., Kohl, S. A., Petersen, J., & Maier-Hein, K. H. (2021). nnU-Net: a self-configuring method for deep learning-based biomedical image segmentation. Nature methods, 18(2), 203-211.
# #######################################################################
#
# 2025-03-28 01:25:23.472735: Using torch.compile...
# 2025-03-28 01:25:32.062194: do_dummy_2d_data_aug: True
# 2025-03-28 01:25:32.069932: Using splits from existing split file: /content/drive/MyDrive/nnUNet/nnUNet_preprocessed/Dataset002_HN/splits_final.json
# ...

# %%
# !nnUNetv2_train 2 3d_cascade_fullres 2 --npz --c
# Out:
# ############################
# INFO: You are using the old nnU-Net default plans. We have updated our recommendations. Please consider using those instead! Read more here: https://github.com/MIC-DKFZ/nnUNet/blob/master/documentation/resenc_presets.md
# ############################
#
# Using device: cuda:0
#
# #######################################################################
# Please cite the following paper when using nnU-Net:
# Isensee, F., Jaeger, P. F., Kohl, S. A., Petersen, J., & Maier-Hein, K. H. (2021). nnU-Net: a self-configuring method for deep learning-based biomedical image segmentation. Nature methods, 18(2), 203-211.
# #######################################################################
#
# 2025-03-28 07:29:59.491638: Using torch.compile...
# 2025-03-28 07:30:08.377747: do_dummy_2d_data_aug: True
# 2025-03-28 07:30:08.385089: Using splits from existing split file: /content/drive/MyDrive/nnUNet/nnUNet_preprocessed/Dataset002_HN/splits_final.json
# ...

# %%
# !nnUNetv2_train 2 3d_cascade_fullres 3 --npz --c
# Out:
# ############################
# INFO: You are using the old nnU-Net default plans. We have updated our recommendations. Please consider using those instead! Read more here: https://github.com/MIC-DKFZ/nnUNet/blob/master/documentation/resenc_presets.md
# ############################
#
# Using device: cuda:0
#
# #######################################################################
# Please cite the following paper when using nnU-Net:
# Isensee, F., Jaeger, P. F., Kohl, S. A., Petersen, J., & Maier-Hein, K. H. (2021). nnU-Net: a self-configuring method for deep learning-based biomedical image segmentation. Nature methods, 18(2), 203-211.
# #######################################################################
#
# 2025-03-28 15:40:14.686529: Using torch.compile...
# 2025-03-28 15:40:28.982169: do_dummy_2d_data_aug: True
# 2025-03-28 15:40:28.988243: Using splits from existing split file: /content/drive/MyDrive/nnUNet/nnUNet_preprocessed/Dataset002_HN/splits_final.json
# ...

# %%
# !nnUNetv2_train 2 3d_cascade_fullres 4 --npz --c
# Out:
# /bin/bash: line 1: nnUNetv2_train: command not found

# %%
# !nnUNetv2_train 2 3d_lowres 0 --npz --c

# %%
# !nnUNetv2_train 2 3d_lowres 1 --npz --c

# %%
# !nnUNetv2_train 2 3d_lowres 2 --npz --c

# %%
# !nnUNetv2_train 2 3d_lowres 3 --npz --c

# %%
# !nnUNetv2_train 2 3d_lowres 4 --npz --c

# %%
# !nnUNetv2_train 2 3d_fullres 0 --npz --c

# %%
# !nnUNetv2_train 2 3d_fullres 1 --npz --c

# %%
# !nnUNetv2_train 2 3d_fullres 2 --npz --c
# Out:
# ############################
# INFO: You are using the old nnU-Net default plans. We have updated our recommendations. Please consider using those instead! Read more here: https://github.com/MIC-DKFZ/nnUNet/blob/master/documentation/resenc_presets.md
# ############################
#
# Using device: cuda:0
#
# #######################################################################
# Please cite the following paper when using nnU-Net:
# Isensee, F., Jaeger, P. F., Kohl, S. A., Petersen, J., & Maier-Hein, K. H. (2021). nnU-Net: a self-configuring method for deep learning-based biomedical image segmentation. Nature methods, 18(2), 203-211.
# #######################################################################
#
# 2025-03-26 20:39:18.782789: Using torch.compile...
# 2025-03-26 20:39:38.536291: do_dummy_2d_data_aug: True
# 2025-03-26 20:39:38.544406: Using splits from existing split file: /content/drive/MyDrive/nnUNet/nnUNet_preprocessed/Dataset002_HN/splits_final.json
# ...

# %%
# !nnUNetv2_train 2 3d_fullres 3 --npz --c
# Out:
# ############################
# INFO: You are using the old nnU-Net default plans. We have updated our recommendations. Please consider using those instead! Read more here: https://github.com/MIC-DKFZ/nnUNet/blob/master/documentation/resenc_presets.md
# ############################
#
# Using device: cuda:0
#
# #######################################################################
# Please cite the following paper when using nnU-Net:
# Isensee, F., Jaeger, P. F., Kohl, S. A., Petersen, J., & Maier-Hein, K. H. (2021). nnU-Net: a self-configuring method for deep learning-based biomedical image segmentation. Nature methods, 18(2), 203-211.
# #######################################################################
#
# 2025-03-27 03:04:04.651952: Using torch.compile...
# 2025-03-27 03:04:15.483618: do_dummy_2d_data_aug: True
# 2025-03-27 03:04:15.523612: Using splits from existing split file: /content/drive/MyDrive/nnUNet/nnUNet_preprocessed/Dataset002_HN/splits_final.json
# ...

# %%
# !nnUNetv2_train 2 3d_fullres 4 --npz --c
# Out:
# ############################
# INFO: You are using the old nnU-Net default plans. We have updated our recommendations. Please consider using those instead! Read more here: https://github.com/MIC-DKFZ/nnUNet/blob/master/documentation/resenc_presets.md
# ############################
#
# Using device: cuda:0
#
# #######################################################################
# Please cite the following paper when using nnU-Net:
# Isensee, F., Jaeger, P. F., Kohl, S. A., Petersen, J., & Maier-Hein, K. H. (2021). nnU-Net: a self-configuring method for deep learning-based biomedical image segmentation. Nature methods, 18(2), 203-211.
# #######################################################################
#
# 2025-03-27 09:28:20.344732: Using torch.compile...
# 2025-03-27 09:28:31.407390: do_dummy_2d_data_aug: True
# 2025-03-27 09:28:31.414590: Using splits from existing split file: /content/drive/MyDrive/nnUNet/nnUNet_preprocessed/Dataset002_HN/splits_final.json
# ...

# %%
#!cp -r nnUNet_preprocessed /content/drive/MyDrive/nnUnet/

# %%
#run only when you get an error related to nnUNet_preprocessed (as we had got in the meeting)
#!rm -rf nnUNet_preprocessed

# %%
#!cp -r /content/drive/MyDrive/nnUnet/nnUNet_preprocessed ./

# %%
# !nnUNetv2_train 2 2d 0 --npz --c

# %%
# !nnUNetv2_train 2 2d 1 --npz --c

# %%
#run this everytime you complete a training
#!cp -r nnUNet_results /content/drive/MyDrive/nnUnet/

# %%
# !nnUNetv2_train 2 2d 2 --npz --c

# %%
# !nnUNetv2_train 2 2d 3 --npz --c

# %%
# !nnUNetv2_train 2 2d 4 --npz --c
